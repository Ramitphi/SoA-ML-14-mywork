# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('D:\week1.csv')

# %%
df.head()
# Out:
#                    Timestamp  \
# 0  2017/10/17 1:11:52 PM MDT
# 1  2017/10/17 2:26:07 PM MDT
# 2  2017/10/17 2:37:08 PM MDT
# 3  2017/10/17 2:39:26 PM MDT
# 4  2017/10/17 2:43:59 PM MDT
#
#   What's your level of interest for the following areas of Data Science? [Data Visualization]  \
# 0                                    Very interested
# 1                                    Very interested
# 2                                     Not interested
# 3                                    Very interested
# 4                                Somewhat interested
#
#   What's your level of interest for the following areas of Data Science? [Machine Learning]  \
# 0                                    Very interested
# 1                                    Very interested
# 2                                    Very interested
# 3                                    Very interested
# 4                                    Very interested
#
# ...

# %%
df1=df.T

# %%
df1.head()
# Out:
#                                                                          0     \
# Timestamp                                           2017/10/17 1:11:52 PM MDT
# What's your level of interest for the following...            Very interested
# What's your level of interest for the following...            Very interested
# What's your level of interest for the following...        Somewhat interested
# What's your level of interest for the following...             Not interested
#
#                                                                          1     \
# Timestamp                                           2017/10/17 2:26:07 PM MDT
# What's your level of interest for the following...            Very interested
# What's your level of interest for the following...            Very interested
# What's your level of interest for the following...            Very interested
# What's your level of interest for the following...        Somewhat interested
#
# ...

# %%
df1["Very interested"]=np.sum(df1=="Very interested",axis=1)

# %%
df1.head()
# Out:
#                                                                             0  \
# Timestamp                                           2017/10/17 1:11:52 PM MDT
# What's your level of interest for the following...            Very interested
# What's your level of interest for the following...            Very interested
# What's your level of interest for the following...        Somewhat interested
# What's your level of interest for the following...             Not interested
#
#                                                                             1  \
# Timestamp                                           2017/10/17 2:26:07 PM MDT
# What's your level of interest for the following...            Very interested
# What's your level of interest for the following...            Very interested
# What's your level of interest for the following...            Very interested
# What's your level of interest for the following...        Somewhat interested
#
# ...

# %%
df1["Not Intrested"]=np.sum(df1=="Not Interested",axis=1)

# %%
df1["Somewhat interested"]=np.sum(df1=="Somewhat interested",axis=1)

# %%
df1.head()
# Out:
#                                                                             0  \
# Timestamp                                           2017/10/17 1:11:52 PM MDT
# What's your level of interest for the following...            Very interested
# What's your level of interest for the following...            Very interested
# What's your level of interest for the following...        Somewhat interested
# What's your level of interest for the following...             Not interested
#
#                                                                             1  \
# Timestamp                                           2017/10/17 2:26:07 PM MDT
# What's your level of interest for the following...            Very interested
# What's your level of interest for the following...            Very interested
# What's your level of interest for the following...            Very interested
# What's your level of interest for the following...        Somewhat interested
#
# ...

# %%
df2=df1.iloc[:,2233:]

# %%
df2.head()
# Out:
#                                                     Very interested  \
# Timestamp                                                         0
# What's your level of interest for the following...             1340
# What's your level of interest for the following...             1629
# What's your level of interest for the following...             1688
# What's your level of interest for the following...             1332
#
#                                                     Not Intrested  \
# Timestamp                                                       0
# What's your level of interest for the following...              0
# What's your level of interest for the following...              0
# What's your level of interest for the following...              0
# What's your level of interest for the following...              0
#
#                                                     Somewhat interested
# Timestamp                                                             0
# ...

# %%
df2 = df2.drop(columns="Not Intrested")
df2.head()
# Out:
#                                                     Very interested  \
# Timestamp                                                         0
# What's your level of interest for the following...             1340
# What's your level of interest for the following...             1629
# What's your level of interest for the following...             1688
# What's your level of interest for the following...             1332
#
#                                                     Somewhat interested
# Timestamp                                                             0
# What's your level of interest for the following...                  734
# What's your level of interest for the following...                  477
# What's your level of interest for the following...                  444
# What's your level of interest for the following...                  729

# %%
df2=df2.iloc[2:,:]

# %%
df2.head()
# Out:
#                                                     Very interested  \
# What's your level of interest for the following...             1629
# What's your level of interest for the following...             1688
# What's your level of interest for the following...             1332
# What's your level of interest for the following...              429
# What's your level of interest for the following...             1263
#
#                                                     Somewhat interested
# What's your level of interest for the following...                  477
# What's your level of interest for the following...                  444
# What's your level of interest for the following...                  729
# What's your level of interest for the following...                 1081
# What's your level of interest for the following...                  770

# %%
df2['Not interested']=np.sum(df1=="Not interested",axis=1)

# %%
df2.head()
# Out:
#                                                     Very interested  \
# What's your level of interest for the following...             1629
# What's your level of interest for the following...             1688
# What's your level of interest for the following...             1332
# What's your level of interest for the following...              429
# What's your level of interest for the following...             1263
#
#                                                     Somewhat interested  \
# What's your level of interest for the following...                  477
# What's your level of interest for the following...                  444
# What's your level of interest for the following...                  729
# What's your level of interest for the following...                 1081
# What's your level of interest for the following...                  770
#
#                                                     Not interested
# ...

# %%
df2.head()
# Out:
#                                                     Very interested  \
# What's your level of interest for the following...             1629
# What's your level of interest for the following...             1688
# What's your level of interest for the following...             1332
# What's your level of interest for the following...              429
# What's your level of interest for the following...             1263
#
#                                                     Somewhat interested  \
# What's your level of interest for the following...                  477
# What's your level of interest for the following...                  444
# What's your level of interest for the following...                  729
# What's your level of interest for the following...                 1081
# What's your level of interest for the following...                  770
#
#                                                     Not interested
# ...

# %%
df2.iloc[:,0]
# Out:
# What's your level of interest for the following areas of Data Science? [Machine Learning]              1629
# What's your level of interest for the following areas of Data Science? [Data Analysis / Statistics]    1688
# What's your level of interest for the following areas of Data Science? [Big Data (Spark / Hadoop)]     1332
# What's your level of interest for the following areas of Data Science? [Data Journalism]                429
# What's your level of interest for the following areas of Data Science? [Deep Learning]                 1263
# Name: Very interested, dtype: int64

# %%
df2.index
# Out:
# Index(['What's your level of interest for the following areas of Data Science? [Machine Learning]',
#        'What's your level of interest for the following areas of Data Science? [Data Analysis / Statistics]',
#        'What's your level of interest for the following areas of Data Science? [Big Data (Spark / Hadoop)]',
#        'What's your level of interest for the following areas of Data Science? [Data Journalism]',
#        'What's your level of interest for the following areas of Data Science? [Deep Learning]'],
#       dtype='object')

# %%
df2=df2.sort_index()

# %%
df2.head()
# Out:
#                                                     Very interested  \
# What's your level of interest for the following...             1332
# What's your level of interest for the following...             1688
# What's your level of interest for the following...              429
# What's your level of interest for the following...             1263
# What's your level of interest for the following...             1629
#
#                                                     Somewhat interested  \
# What's your level of interest for the following...                  729
# What's your level of interest for the following...                  444
# What's your level of interest for the following...                 1081
# What's your level of interest for the following...                  770
# What's your level of interest for the following...                  477
#
#                                                     Not interested
# ...

# %%
df2.head()
# Out:
#                                                     Very interested  \
# What's your level of interest for the following...             1629
# What's your level of interest for the following...             1688
# What's your level of interest for the following...             1332
# What's your level of interest for the following...              429
# What's your level of interest for the following...             1263
#
#                                                     Somewhat interested  \
# What's your level of interest for the following...                  477
# What's your level of interest for the following...                  444
# What's your level of interest for the following...                  729
# What's your level of interest for the following...                 1081
# What's your level of interest for the following...                  770
#
#                                                     Not interested
# ...

# %%
s1=df2.iloc[0:]

# %%
s1
# Out:
#                                                     Very interested  \
# What's your level of interest for the following...             1629
# What's your level of interest for the following...             1688
# What's your level of interest for the following...             1332
# What's your level of interest for the following...              429
# What's your level of interest for the following...             1263
#
#                                                     Somewhat interested  \
# What's your level of interest for the following...                  477
# What's your level of interest for the following...                  444
# What's your level of interest for the following...                  729
# What's your level of interest for the following...                 1081
# What's your level of interest for the following...                  770
#
#                                                     Not interested
# ...

# %%
res=df2.div(df2.sum(axis=1),axis=0)*100

# %%
res.head()
# Out:
#                                                     Very interested  \
# What's your level of interest for the following...        74.724771
# What's your level of interest for the following...        77.007299
# What's your level of interest for the following...        60.877514
# What's your level of interest for the following...        20.235849
# What's your level of interest for the following...        58.229599
#
#                                                     Somewhat interested  \
# What's your level of interest for the following...            21.880734
# What's your level of interest for the following...            20.255474
# What's your level of interest for the following...            33.318099
# What's your level of interest for the following...            50.990566
# What's your level of interest for the following...            35.500231
#
#                                                     Not interested
# ...

# %%
df2.plot(kind='bar')
